# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list

import random

# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.

game = ['stone', 'paper', 'scissors']


# Assign a variable to the maximum number of games: 1, 3, 5, etc ...

num_games = input("Number of Games?")
type(num_games)

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games

num_wins = int(int(num_games)/2)

print("You need to win", num_wins, "times")

# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.

machine = random.choice(game)

# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.


# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins


    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
    
# Create two variables that accumulate the wins of each participant

victory = 0
player_victories = 0
machine_victories = 0
ties = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

while (int(machine_victories) < int(num_wins)) or (int(player_victories) < int(num_wins)):
        
    machine = random.choice(game)
    player = input("What would be your game?")
    type(player)
    if player not in game:
        player = input("Please pick another one rock, paper and scissor")
        type(player)
    
    print("machine: ", machine, "vs", "player: ", player )
    
    if player == machine:
        victory = 0
    elif (machine == 'stone' and player == 'scissors') or (machine == 'paper' and player == 'stone') or (machine == 'scissors' and player == 'paper'):
        victory = 1
    else:
        victory = 2
    
    if victory == 0:
        result = print("It's a tie")
    elif victory == 1:
        result = print("Machine win")
    else:
        result = print("User win")
    
    if victory == 1:
        machine_victories +=1
    elif victory == 2:
        player_victories +=1
    else:
        ties +=1
    
    print("Player: ", player_victories, " Machine: ", machine_victories)
else:
    if int(machine_victories) > int (player_victories):
        print("Matchin win: ", machine_victories, " vs ", player_victories)
    else:
        print("User win: ", player_victories, "vs", machine_victories)


# Print by console the winner of the game based on who has more accumulated wins
# Out:
# Number of Games?5
# You need to win 2 times
# What would be your game?stone
# machine:  paper vs player:  stone
# Machine win
# Player:  0  Machine:  1
# What would be your game?stone
# machine:  paper vs player:  stone
# Machine win
# Player:  0  Machine:  2
# What would be your game?stone
# machine:  paper vs player:  stone
# Machine win
# Player:  0  Machine:  3
# What would be your game?stone
# machine:  stone vs player:  stone
# It's a tie
# Player:  0  Machine:  3
# What would be your game?stone
# machine:  stone vs player:  stone
# It's a tie
# Player:  0  Machine:  3
# What would be your game?stone
# machine:  stone vs player:  stone
# It's a tie
# Player:  0  Machine:  3
# What would be your game?stone
# machine:  paper vs player:  stone
# Machine win
# Player:  0  Machine:  4
# What would be your game?stone
# machine:  scissors vs player:  stone
# User win
# Player:  1  Machine:  4
